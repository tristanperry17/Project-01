# %%
# Dependencies
import hvplot.pandas
import requests
import pandas as pd
import json
from pprint import pprint
import hvplot.pandas
# Import the API key
from config import geoapify_key
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>

# %%
# Target city
target_county1 = "Carteret County"
target_county2 = "Dare County"
target_county3 = "Hyde County"

# Build the endpoint URL
target_url1 = f"https://api.geoapify.com/v1/geocode/search?text={target_county1}&format=json&apiKey={geoapify_key}"
target_url2 = f"https://api.geoapify.com/v1/geocode/search?text={target_county2}&format=json&apiKey={geoapify_key}"
target_url3 = f"https://api.geoapify.com/v1/geocode/search?text={target_county3}&format=json&apiKey={geoapify_key}"

# %%
# Run a request to endpoint and convert result to json

geo_data1 = requests.get(target_url1).json()
geo_data2 = requests.get(target_url2).json()
geo_data3 = requests.get(target_url3).json()
# Print the json
pprint(geo_data1)
pprint(geo_data2)
pprint(geo_data3)
# Out:
# {'query': {'parsed': {'county': 'carteret county', 'expected_type': 'unknown'},
#            'text': 'Carteret County'},
#  'results': [{'address_line1': 'Carteret, NC',
#               'address_line2': 'United States of America',
#               'bbox': {'lat1': 34.531736,
#                        'lat2': 35.2014775,
#                        'lon1': -77.1677717,
#                        'lon2': -76.006557},
#               'category': 'administrative',
#               'country': 'United States',
#               'country_code': 'us',
#               'county': 'Carteret',
#               'datasource': {'attribution': '© OpenStreetMap contributors',
#                              'license': 'Open Database License',
#                              'sourcename': 'openstreetmap',
#                              'url': 'https://www.openstreetmap.org/copyright'},
#               'formatted': 'Carteret, NC, United States of America',
#               'lat': 34.8496625,
#               'lon': -76.5931208,
#               'place_id': '51f3a4f1b0f52553c0599d11a5bdc16c4140f00101f901aa95260000000000c00209',
#               'plus_code': '8765RCX4+VQ',
#               'rank': {'confidence': 1,
#                        'importance': 0.7260103474530113,
#                        'match_type': 'full_match',
#                        'popularity': 1.3263965232936872},
#               'result_type': 'county',
#               'state': 'North Carolina',
#               'state_code': 'NC',
#               'timezone': {'abbreviation_DST': 'EDT',
#                            'abbreviation_STD': 'EST',
#                            'name': 'America/New_York',
#                            'offset_DST': '-04:00',
#                            'offset_DST_seconds': -14400,
#                            'offset_STD': '-05:00',
#                            'offset_STD_seconds': -18000}}]}
# {'query': {'parsed': {'county': 'dare county', 'expected_type': 'unknown'},
#            'text': 'Dare County'},
#  'results': [{'address_line1': 'Dare, NC',
#               'address_line2': 'United States of America',
#               'bbox': {'lat1': 35.140565,
#                        'lat2': 36.244984,
#                        'lon1': -76.0274812,
#                        'lon2': -75.400119},
#               'category': 'administrative',
#               'country': 'United States',
#               'country_code': 'us',
#               'county': 'Dare',
#               'datasource': {'attribution': '© OpenStreetMap contributors',
#                              'license': 'Open Database License',
#                              'sourcename': 'openstreetmap',
#                              'url': 'https://www.openstreetmap.org/copyright'},
#               'formatted': 'Dare, NC, United States of America',
#               'lat': 35.6333866,
#               'lon': -75.6869011,
#               'place_id': '5188050830f6eb52c059c15ce6cf12d14140f00101f9018bcd120000000000c00209',
#               'plus_code': '8776J8M7+96',
#               'rank': {'confidence': 1,
#                        'importance': 0.7244524349266244,
#                        'match_type': 'full_match',
#                        'popularity': 1.1312951076377313},
#               'result_type': 'county',
#               'state': 'North Carolina',
#               'state_code': 'NC',
#               'timezone': {'abbreviation_DST': 'EDT',
#                            'abbreviation_STD': 'EST',
#                            'name': 'America/New_York',
#                            'offset_DST': '-04:00',
#                            'offset_DST_seconds': -14400,
#                            'offset_STD': '-05:00',
#                            'offset_STD_seconds': -18000}}]}
# {'query': {'parsed': {'county': 'hyde county', 'expected_type': 'unknown'},
#            'text': 'Hyde County'},
#  'results': [{'address_line1': 'Hyde, NC',
#               'address_line2': 'United States of America',
#               'bbox': {'lat1': 35.006031,
#                        'lat2': 35.7052229,
#                        'lon1': -76.6375129,
#                        'lon2': -75.73662},
#               'category': 'administrative',
#               'country': 'United States',
#               'country_code': 'us',
#               'county': 'Hyde',
#               'datasource': {'attribution': '© OpenStreetMap contributors',
#                              'license': 'Open Database License',
#                              'sourcename': 'openstreetmap',
#                              'url': 'https://www.openstreetmap.org/copyright'},
#               'formatted': 'Hyde, NC, United States of America',
#               'lat': 35.3935017,
#               'lon': -76.1253302,
#               'place_id': '51df8cf568050853c059d03582435eb24140f00101f90181dd120000000000c00209',
#               'plus_code': '87759VVF+CV',
#               'rank': {'confidence': 1,
#                        'importance': 0.7228030985670573,
#                        'match_type': 'full_match',
#                        'popularity': 1.2085822720670207},
#               'result_type': 'county',
#               'state': 'North Carolina',
#               'state_code': 'NC',
#               'timezone': {'abbreviation_DST': 'EDT',
#                            'abbreviation_STD': 'EST',
#                            'name': 'America/New_York',
#                            'offset_DST': '-04:00',
#                            'offset_DST_seconds': -14400,
#                            'offset_STD': '-05:00',
#                            'offset_STD_seconds': -18000}},
#              {'address_line1': 'Hyde, SD',
#               'address_line2': 'United States of America',
#               'bbox': {'lat1': 44.193073,
#                        'lat2': 44.898617,
#                        'lon1': -99.675003,
#                        'lon2': -99.299912},
#               'category': 'administrative',
#               'country': 'United States',
#               'country_code': 'us',
#               'county': 'Hyde',
#               'datasource': {'attribution': '© OpenStreetMap contributors',
#                              'license': 'Open Database License',
#                              'sourcename': 'openstreetmap',
#                              'url': 'https://www.openstreetmap.org/copyright'},
#               'formatted': 'Hyde, SD, United States of America',
#               'lat': 44.5103405,
#               'lon': -99.4936719,
#               'place_id': '51115d065298df58c05982a966d652414640f00101f9012f8c1a0000000000c00209',
#               'plus_code': '86P2GG64+4G',
#               'rank': {'confidence': 1,
#                        'importance': 0.6721692865728439,
#                        'match_type': 'full_match',
#                        'popularity': 0.7141446571079781},
#               'result_type': 'county',
#               'state': 'South Dakota',
#               'state_code': 'SD',
#               'timezone': {'abbreviation_DST': 'CDT',
#                            'abbreviation_STD': 'CST',
#                            'name': 'America/Chicago',
#                            'offset_DST': '-05:00',
#                            'offset_DST_seconds': -18000,
#                            'offset_STD': '-06:00',
#                            'offset_STD_seconds': -21600}},
#              {'address_line1': 'Hyde County, NC',
#               'address_line2': 'United States of America',
#               'bbox': {'lat1': 35.6602084,
#                        'lat2': 35.6689082,
#                        'lon1': -75.9084994,
#                        'lon2': -75.8979466},
#               'category': 'natural.protected_area',
#               'country': 'United States',
#               'country_code': 'us',
#               'county': 'Hyde County',
#               'datasource': {'attribution': '© OpenStreetMap contributors',
#                              'license': 'Open Database License',
#                              'sourcename': 'openstreetmap',
#                              'url': 'https://www.openstreetmap.org/copyright'},
#               'formatted': 'Hyde County, NC, United States of America',
#               'lat': 35.6640844,
#               'lon': -75.90421612679594,
#               'name': 'Hyde County',
#               'place_id': '51ae4651addef952c05953e4b5b700d54140f00102f901c03ff90100000000c0020992030b4879646520436f756e7479',
#               'plus_code': '8776M37W+J8',
#               'rank': {'confidence': 1,
#                        'importance': 0.32500999999999997,
#                        'match_type': 'full_match',
#                        'popularity': 1.112424239116706},
#               'result_type': 'county',
#               'state': 'North Carolina',
#               'state_code': 'NC',
#               'timezone': {'abbreviation_DST': 'EDT',
#                            'abbreviation_STD': 'EST',
#                            'name': 'America/New_York',
#                            'offset_DST': '-04:00',
#                            'offset_DST_seconds': -14400,
#                            'offset_STD': '-05:00',
#                            'offset_STD_seconds': -18000}}]}

# %%
# Extract latitude and longitude
lat1 = geo_data1['results'][0]['lat']
lon1 = geo_data1['results'][0]['lon']

lat2 = geo_data2['results'][0]['lat']
lon2 = geo_data2['results'][0]['lon']

lat3 = geo_data3['results'][0]['lat']
lon3 = geo_data3['results'][0]['lon']

# Print the latitude and longitude
print("""
    County: {0}
    Latitude: {1}
    Longitude: {2}
    """.format(target_county1, lat1, lon1))

print("""
    County: {0}
    Latitude: {1}
    Longitude: {2}
    """.format(target_county2, lat2, lon2))

print("""
    County: {0}
    Latitude: {1}
    Longitude: {2}
    """.format(target_county3, lat3, lon3))
# Out:
#     County: Carteret County
#     Latitude: 34.8496625
#     Longitude: -76.5931208
#
#
#     County: Dare County
#     Latitude: 35.6333866
#     Longitude: -75.6869011
#
#
#     County: Hyde County
#     Latitude: 35.3935017
#     Longitude: -76.1253302

# %%
coordinates = {
    "latitude": [lat1, lat2, lat3],
    "longitude": [lon1, lon2, lon3],
    "County": ["Carteret County", "Dare County", "Hyde County"],
    
}

# %%
# Create a Pandas DataFrame containing coordinates
coordinates_df = pd.DataFrame(coordinates)

# Display sample data
coordinates_df
# Out:
#     latitude  longitude           County
# 0  34.849663 -76.593121  Carteret County
# 1  35.633387 -75.686901      Dare County
# 2  35.393502 -76.125330      Hyde County

# %%
# Configure the map 
map_plot_1 = coordinates_df.hvplot.points(
    'longitude', 
    'latitude', 
    geo=True,
    tiles='OSM',
    frame_width=700,
    frame_height=600,
    scale= 0.01,
    color='County')

# Display the map 
map_plot_1
# Out:
# :Overlay
#    .Tiles.I  :Tiles   [x,y]
#    .Points.I :Points   [longitude,latitude]   (County)
